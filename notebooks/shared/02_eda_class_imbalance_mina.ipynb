# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

DATA_ROOT = Path("../../data/raw/mvtec_ad")
categories = sorted([d.name for d in DATA_ROOT.iterdir() if d.is_dir() and (d / "test").exists()])
print(categories)
# Out:
# ['bottle', 'cable', 'capsule', 'carpet', 'grid', 'hazelnut', 'leather', 'metal_nut', 'pill', 'screw', 'tile', 'toothbrush', 'transistor', 'wood', 'zipper']

# %%
records = []

for category in categories:
    test_dir = DATA_ROOT / category / "test"
    for subfolder in sorted(test_dir.iterdir()):
        if not subfolder.is_dir():
            continue
        n_images = len(list(subfolder.glob("*.png")))
        label = "good" if subfolder.name == "good" else "defective"
        records.append({"category": category, "subfolder": subfolder.name, "label": label, "count": n_images})

df = pd.DataFrame(records)
df.head(20)
# Out:
#    category             subfolder      label  count
# 0    bottle          broken_large  defective     20
# 1    bottle          broken_small  defective     22
# 2    bottle         contamination  defective     21
# 3    bottle                  good       good     20
# 4     cable             bent_wire  defective     13
# 5     cable            cable_swap  defective     12
# 6     cable              combined  defective     11
# 7     cable  cut_inner_insulation  defective     14
# 8     cable  cut_outer_insulation  defective     10
# 9     cable                  good       good     58
# 10    cable         missing_cable  defective     12
# 11    cable          missing_wire  defective     10
# 12    cable       poke_insulation  defective     10
# 13  capsule                 crack  defective     23
# 14  capsule        faulty_imprint  defective     22
# 15  capsule                  good       good     23
# 16  capsule                  poke  defective     21
# ...

# %%
category_counts = df.groupby(["category", "label"])["count"].sum().unstack(fill_value=0)
category_counts["total"] = category_counts["good"] + category_counts["defective"]
category_counts["defective_ratio"] = category_counts["defective"] / category_counts["total"]
category_counts
# Out:
# label       defective  good  total  defective_ratio
# category
# bottle             63    20     83         0.759036
# cable              92    58    150         0.613333
# capsule           109    23    132         0.825758
# carpet             89    28    117         0.760684
# grid               57    21     78         0.730769
# hazelnut           70    40    110         0.636364
# leather            92    32    124         0.741935
# metal_nut          93    22    115         0.808696
# pill              141    26    167         0.844311
# screw             119    41    160         0.743750
# tile               84    33    117         0.717949
# toothbrush         30    12     42         0.714286
# transistor         40    60    100         0.400000
# wood               60    19     79         0.759494
# zipper            119    32    151         0.788079

# %%
from scipy.stats import chi2_contingency

contingency_table = category_counts[["good", "defective"]]
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-square statistic: {chi2:.3f}")
print(f"Degrees of freedom: {dof}")
print(f"p-value: {p_value:.2e}")
# Out:
# Chi-square statistic: 95.392
# Degrees of freedom: 14
# p-value: 3.60e-14

# %%
import numpy as np
from PIL import Image

sample_mask_path = DATA_ROOT / "bottle" / "ground_truth" / "broken_large" / "000_mask.png"
mask = np.array(Image.open(sample_mask_path))

print("Shape:", mask.shape)
print("Unique values:", np.unique(mask))
print("Anomalous pixels:", (mask > 0).sum())
print("Total pixels:", mask.size)
# Out:
# Shape: (900, 900)
# Unique values: [  0 255]
# Anomalous pixels: 88192
# Total pixels: 810000

# %%
pixel_records = []

for category in categories:
    gt_dir = DATA_ROOT / category / "ground_truth"
    if not gt_dir.exists():
        continue
    for defect_type_dir in sorted(gt_dir.iterdir()):
        if not defect_type_dir.is_dir():
            continue
        for mask_path in sorted(defect_type_dir.glob("*_mask.png")):
            mask = np.array(Image.open(mask_path))
            anomalous = int((mask > 0).sum())
            normal = int(mask.size - anomalous)
            pixel_records.append({
                "category": category,
                "defect_type": defect_type_dir.name,
                "anomalous_pixels": anomalous,
                "normal_pixels": normal
            })

pixel_df = pd.DataFrame(pixel_records)
pixel_df.head(10)
# Out:
#   category   defect_type  anomalous_pixels  normal_pixels
# 0   bottle  broken_large             88192         721808
# 1   bottle  broken_large             76641         733359
# 2   bottle  broken_large            125835         684165
# 3   bottle  broken_large            222091         587909
# 4   bottle  broken_large             33132         776868
# 5   bottle  broken_large             33201         776799
# 6   bottle  broken_large            123810         686190
# 7   bottle  broken_large            130952         679048
# 8   bottle  broken_large            105614         704386
# 9   bottle  broken_large             70875         739125

# %%
category_pixel_totals = pixel_df.groupby("category")[["anomalous_pixels", "normal_pixels"]].sum()
category_pixel_totals["total_pixels"] = category_pixel_totals["anomalous_pixels"] + category_pixel_totals["normal_pixels"]
category_pixel_totals["anomalous_ratio"] = category_pixel_totals["anomalous_pixels"] / category_pixel_totals["total_pixels"]
category_pixel_totals.sort_values("anomalous_ratio")
# Out:
#             anomalous_pixels  normal_pixels  total_pixels  anomalous_ratio
# category
# screw                 418611      124361933     124780544         0.003355
# leather               843352       95625640      96468992         0.008742
# grid                  564944       59203888      59768832         0.009452
# capsule              1208676      107791324     109000000         0.011089
# carpet               1965794       91357470      93323264         0.021064
# toothbrush            673493       30783787      31457280         0.021410
# zipper               3274311      121506233     124780544         0.026241
# hazelnut             2462314       70938006      73400320         0.033546
# pill                 3589160       86650840      90240000         0.039773
# cable                4515876       91953116      96468992         0.046812
# wood                 3199416       59715144      62914560         0.050853
# ...

# %%
category_pixel_totals.loc["metal_nut"]
# Out:
# anomalous_pixels    6.602541e+06
# normal_pixels       3.896746e+07
# total_pixels        4.557000e+07
# anomalous_ratio     1.448879e-01
# Name: metal_nut, dtype: float64

# %%
pixel_df.assign(
    anomalous_ratio=pixel_df["anomalous_pixels"] / (pixel_df["anomalous_pixels"] + pixel_df["normal_pixels"])
)[pixel_df["category"] == "metal_nut"].sort_values("anomalous_ratio", ascending=False).head(10)
# Out:
#       category defect_type  anomalous_pixels  normal_pixels  anomalous_ratio
# 636  metal_nut        flip            238751         251249         0.487247
# 620  metal_nut        flip            238718         251282         0.487180
# 635  metal_nut        flip            238493         251507         0.486720
# 622  metal_nut        flip            238487         251513         0.486708
# 626  metal_nut        flip            237959         252041         0.485631
# 619  metal_nut        flip            237351         252649         0.484390
# 638  metal_nut        flip            236666         253334         0.482992
# 628  metal_nut        flip            236366         253634         0.482380
# 621  metal_nut        flip            236355         253645         0.482357
# 629  metal_nut        flip            236323         253677         0.482292

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sorted_pixel = category_pixel_totals.sort_values("anomalous_ratio")

ax.barh(sorted_pixel.index, sorted_pixel["anomalous_ratio"] * 100, color="#C44E52")
ax.set_xlabel("Anomalous pixel ratio (%)")
ax.set_title("Pixel-Level Class Imbalance: Anomalous Pixel Ratio per Category")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Key Insight: Image-Level vs. Pixel-Level Imbalance Diverge
#
# Image-level and pixel-level imbalance tell very different stories. A category like
# **"screw"** might have plenty of defective *images*, but each defect covers only a
# tiny fraction of the image (0.34% anomalous pixels). In contrast, **"metal_nut"**
# defects are much larger and more pervasive within the image (14.5% anomalous pixels)
# — a **~40x difference** in severity, despite both categories having similarly
# proportioned counts of defective vs. good *images*.
# ###### Short Insight: image-level and pixel-level imbalance diverge sharply (screw ~0.3% vs metal_nut ~14.5%)

# %% [markdown]
# Chi-Square test cell on the pixel-level table:

# %%
pixel_contingency_table = category_pixel_totals[["anomalous_pixels", "normal_pixels"]]
chi2_px, p_value_px, dof_px, expected_px = chi2_contingency(pixel_contingency_table)

print(f"Chi-square statistic: {chi2_px:.3f}")
print(f"Degrees of freedom: {dof_px}")
print(f"p-value: {p_value_px:.2e}")
# Out:
# Chi-square statistic: 41675265.648
# Degrees of freedom: 14
# p-value: 0.00e+00

# %% [markdown]
# with millions of pixels, chi-square tests become extremely sensitive — even tiny, practically meaningless differences would register as "significant" at this sample size. The p-value being essentially zero is expected and somewhat less informative here than the effect size itself — the actual 40x range in anomalous_ratio (0.34% to 14.5%) is the number that matters for the business argument, not the p-value alone.
# more explanation:
# look at the category_pixel_totals table, sorted by anomalous_ratio
# screw — lowest — anomalous_ratio = 0.003355 → 0.34%
# metal_nut — highest — anomalous_ratio = 0.144888 → 14.5%
# 0.144888​/0.003355​≈43.2
# So metal_nut's anomalous pixel ratio is about 43 times higher than screw's — that's where the "~40x" figure comes from. It's the ratio between the smallest and largest values in that anomalous_ratio column across all 15 categories.

# %%
pixel_df["anomalous_ratio"] = pixel_df["anomalous_pixels"] / (pixel_df["anomalous_pixels"] + pixel_df["normal_pixels"])
pixel_df[["category", "defect_type", "anomalous_ratio"]].head(10)
# Out:
#   category   defect_type  anomalous_ratio
# 0   bottle  broken_large         0.108879
# 1   bottle  broken_large         0.094619
# 2   bottle  broken_large         0.155352
# 3   bottle  broken_large         0.274186
# 4   bottle  broken_large         0.040904
# 5   bottle  broken_large         0.040989
# 6   bottle  broken_large         0.152852
# 7   bottle  broken_large         0.161669
# 8   bottle  broken_large         0.130388
# 9   bottle  broken_large         0.087500

# %%
pixel_df.columns.tolist()
# Out:
# ['category',
#  'defect_type',
#  'anomalous_pixels',
#  'normal_pixels',
#  'anomalous_ratio']

# %% [markdown]
# already visible here: within just bottle/broken_large, individual images range from 4.1% to 27.4% anomalous — a 6-7x spread within a single category and defect type. This confirms there's real per-image variance worth visualizing, not just category-level differences.

# %% [markdown]
# Build the boxplot

# %%
fig, ax = plt.subplots(figsize=(12, 6))
pixel_df.boxplot(column="anomalous_ratio", by="category", ax=ax, rot=45)
ax.set_ylabel("Anomalous pixel ratio (per image)")
ax.set_title("Anomaly Size Distribution by Category")
plt.suptitle("")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 7))

# Order categories by median, so the chart tells a clearer story left-to-right
order = pixel_df.groupby("category")["anomalous_ratio"].median().sort_values().index
data_ordered = [pixel_df[pixel_df["category"] == cat]["anomalous_ratio"].values for cat in order]

order = list(pixel_df.groupby("category")["anomalous_ratio"].median().sort_values().index)
data_ordered = [pixel_df[pixel_df["category"] == cat]["anomalous_ratio"].values for cat in order]


bp = ax.boxplot(data_ordered, tick_labels=order, patch_artist=True, showmeans=False)

# Color the boxes
for box in bp['boxes']:
    box.set_facecolor("#4C72B0")
    box.set_alpha(0.6)

# Log scale fixes the "everything squished near 0" problem
ax.set_yscale("log")
ax.set_ylabel("Anomalous pixel ratio (per image, log scale)")
ax.set_xlabel("Category")
ax.set_title("Anomaly Size Distribution by Category")

# Add median value labels above each box
medians = [d.mean() for d in data_ordered]  # or use np.median(d)
import numpy as np
for i, d in enumerate(data_ordered):
    med = np.median(d)
    ax.text(i + 1, med * 1.3, f"{med:.1%}", ha="center", fontsize=8, color="darkred")

plt.xticks(rotation=45, ha="right")
ax.grid(True, which="both", ls="--", alpha=0.4)
plt.tight_layout()
plt.savefig("figures/figure_7a_anomaly_size_distribution.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
from scipy.stats import kruskal

groups = [group["anomalous_ratio"].values for name, group in pixel_df.groupby("category")]
h_stat, p_value_kw = kruskal(*groups)

print(f"H-statistic: {h_stat:.3f}")
print(f"p-value: {p_value_kw:.2e}")
# Out:
# H-statistic: 626.507
# p-value: 1.21e-124
